# %%
import pandas as pd

housing_csv = "housing_tr10.csv"
employment_csv = "employment_tr10.csv"
income_csv = "income_tr10.csv"
population_csv = "population_tr10.csv"

housing_df = pd.read_csv(housing_csv)
employment_df = pd.read_csv(employment_csv)
income_df = pd.read_csv(income_csv)
population_df = pd.read_csv(population_csv)

len(housing_df)
# Out:
# 32095

# %%
housing_df_dc = housing_df.loc[(housing_df["ucounty"] == "District of Columbia") & (housing_df["end_date"] == "31DEC2016") & (housing_df["start_date"] == "01JAN2012")]

#housing_df_dc.tail()
#print(housing_df.count())
len(housing_df_dc)
# Out:
# 178

# %%
housing_df_dc.head()
# Out:
#   timeframe        geo2010 NumOccupiedHsgUnits NumOccupiedHsgUnits_m  \
# 0   2012-16     DC Tract 1                2454                   185
# 1   2012-16  DC Tract 2.01                 3.0                   4.0
# 2   2012-16  DC Tract 2.02                1585                   146
# 3   2012-16     DC Tract 3                2544                   124
# 4   2012-16     DC Tract 4                 645                    54
#
#     geo2010_nf start_date   end_date PctSameHouse5YearsAgo  \
# 0  11001000100  01JAN2012  31DEC2016                     .
# 1  11001000201  01JAN2012  31DEC2016                     .
# 2  11001000202  01JAN2012  31DEC2016                     .
# 3  11001000300  01JAN2012  31DEC2016                     .
# 4  11001000400  01JAN2012  31DEC2016                     .
#
#   PctVacantHsgUnitsForRent PctOwnerOccupiedHsgUnits  ...  \
# 0                      9.3                       52  ...
# 1                        i                      100  ...
# ...

# %%
#employment_df
employment_df_dc = employment_df.loc[(employment_df["ucounty"] == "District of Columbia") & (employment_df["end_date"] == "31DEC2016") & (employment_df["start_date"] == "01JAN2012")]

#housing_df_dc.tail()
#print(housing_df.count())
len(employment_df_dc)
# Out:
# 178

# %%
employment_df_dc.head()
# Out:
#   timeframe        geo2010   geo2010_nf start_date   end_date PctUnemployed  \
# 0   2012-16     DC Tract 1  11001000100  01JAN2012  31DEC2016           4.2
# 1   2012-16  DC Tract 2.01  11001000201  01JAN2012  31DEC2016           6.6
# 2   2012-16  DC Tract 2.02  11001000202  01JAN2012  31DEC2016           4.7
# 3   2012-16     DC Tract 3  11001000300  01JAN2012  31DEC2016           2.1
# 4   2012-16     DC Tract 4  11001000400  01JAN2012  31DEC2016           0.5
#
#   Pct16andOverEmployed PctUnemployed_m Pct16andOverEmployed_m  \
# 0                   73             3.5                    8.6
# 1                   41             5.9                    8.7
# 2                   57             3.1                    4.4
# 3                   80             2.4                    5.8
# 4                   64             7.1                    8.0
#
#                 ucounty  indc
# 0  District of Columbia     1
# 1  District of Columbia     1
# 2  District of Columbia     1
# ...

# %%
income_df_dc = income_df.loc[(income_df["ucounty"] == "District of Columbia") & (income_df["end_date"] == "31DEC2016") & (income_df["start_date"] == "01JAN2012")]

#housing_df_dc.tail()
#print(housing_df.count())
len(income_df_dc)
# Out:
# 178

# %%
income_df_dc.head()
# Out:
#   timeframe        geo2010   geo2010_nf start_date   end_date PctPoorPersons  \
# 0   2012-16     DC Tract 1  11001000100  01JAN2012  31DEC2016            3.3
# 1   2012-16  DC Tract 2.01  11001000201  01JAN2012  31DEC2016             66
# 2   2012-16  DC Tract 2.02  11001000202  01JAN2012  31DEC2016             21
# 3   2012-16     DC Tract 3  11001000300  01JAN2012  31DEC2016             17
# 4   2012-16     DC Tract 4  11001000400  01JAN2012  31DEC2016             10
#
#   PctPoorChildren PctPoorElderly AvgFamilyIncAdj PctPoorPersons_m  \
# 0             0.0            2.3          401114              3.5
# 1               i            0.0               .               46
# 2             3.2            3.6          275614              9.0
# 3             2.5             11          237089              7.8
# 4             8.4            2.8          486400              5.1
#
#   PctPoorChildren_m PctPoorElderly_m AvgFamilyIncAdj_m PctChgAvgFamilyIncAdj  \
# ...

# %%
population_df_dc = population_df.loc[(population_df["ucounty"] == "District of Columbia") & (population_df["end_date"] == "31DEC2016") & (population_df["start_date"] == "01JAN2012")]

#housing_df_dc.tail()
#print(housing_df.count())
len(population_df_dc)
# Out:
# 178

# %%
population_df_dc.head()
# Out:
#   timeframe        geo2010 TotPop TotPop_m   geo2010_nf start_date   end_date  \
# 0   2012-16     DC Tract 1   5005      401  11001000100  01JAN2012  31DEC2016
# 1   2012-16  DC Tract 2.01   3733      361  11001000201  01JAN2012  31DEC2016
# 2   2012-16  DC Tract 2.02   4417      556  11001000202  01JAN2012  31DEC2016
# 3   2012-16     DC Tract 3   6139      632  11001000300  01JAN2012  31DEC2016
# 4   2012-16     DC Tract 4   1607      159  11001000400  01JAN2012  31DEC2016
#
#   PctPopUnder18Years PctPop65andOverYears PctForeignBorn  ...  \
# 0                 16                   16             20  ...
# 1                1.2                  0.3             15  ...
# 2                8.7                   13             20  ...
# 3                 13                  8.3             17  ...
# 4                 19                   22             25  ...
#
#   PctBlackNonHispBridge_m PctWhiteNonHispBridge_m PctHisp_m  \
# ...
